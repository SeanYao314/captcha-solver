# %%
import keras 
import tensorflow as tf
import numpy as np
import numba as nb
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
def showImage(im):
    im = np.array(im)
    if(len(im.shape)==1):
        plt.imshow([im],cmap = plt.cm.binary)
        return
    plt.imshow(im,cmap = plt.cm.binary)

# %%
# def initImages():
names = []
path = "/Users/seanyao/cs/ML Keras/CTC/IAM_Words/words/"
top = sorted(os.listdir(path))[1:]
for sup in top:
    for sub in sorted(os.listdir(path+str(sup)+"/"))[1:]:
        for name in sorted(os.listdir(path+str(sup)+"/"+str(sub))):
            names.append(path+str(sup)+"/"+str(sub) + "/" + name)

# %%
ims = []
for i in names[0:1000]:
    ims.append(Image.open(i))

# %%
labels_pre = open("/Users/seanyao/cs/ML Keras/CTC/IAM_Words/words.txt")
labels = labels_pre.readlines()[18:1018]
labels_pre.close()

# %%
showImage(ims[500])
print(labels[500])
# Out:
# a01-007x-01-07 ok 175 1905 1067 363 83 NN sentiment

# %%
a = 'hello'
print(a[:1])
# Out:
# h
